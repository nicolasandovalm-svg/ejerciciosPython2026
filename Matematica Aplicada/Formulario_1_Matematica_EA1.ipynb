# %% [markdown]
# # Formulario Python para MAT2121

# %% [markdown]
# ## Importar bibliotecas o librerías

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import fsolve

# %% [markdown]
# ## Definición de una función

# %%
def f(x):
    return #expresión de la función

# %% [markdown]
# ## Determinar el valor de "**x**" dado el valor de una función F(x)= **b**

# %%
import numpy as np
from scipy.optimize import fsolve

def F(x):
    return #expresión de la función

#Definir la nueva función igualando a cero
def f(x):
    return F(x)- b

#Valor/es inicial/es de la aproximación
x = np.linspace(valor inicial, valor final, cantidad de valores del arreglo)
solucion = fsolve(f, x)

print(f'El valor de x es {solucion[0]}')

# %% [markdown]
# ## Graficar una función

# %%
import numpy as np
import matplotlib.pyplot as plt

def f(x):
    return # función a graficar

x = np.arange(valor inicial, valor final, paso)
plt.plot(x, f(x), label = 'f(x)')
plt.title('Título del gráfico')
plt.xlabel('Nombre eje x')
plt.ylabel('Nombre eje y')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ## Determinar forma algebraica de una función lineal conocidos valores de
#
#  **x** (variable independiente)
#
#  **y** (variable dependiente)

# %%
import numpy as np
x = np.array([valor 1, valor 2, valor 3, …, valor n])
y = np.array([valor 1, valor 2, valor 3, …, valor n])
#Si la función es de grado 1
pendiente, intercepto = np.polyfit(x, y, 1)
print(f'La pendiente es {pendiente} y el intercepto es {intercepto}')
print(f'La función es f(x)={pendiente:.2f}*x +{intercepto:.2f}') #Ajustar decimales según la pregunta

# %% [markdown]
# ## Determinar el punto de intersección de dos funciones lineales:

# %%
import numpy as np
from scipy.optimize import fsolve

def f(x):
    return #expresión de f(x)

def g(x):
    return #expresión de g(x)

#definir una nueva función f(x)-g(x)

def interseccion(x):
    return f(x)-g(x)

x=np.linspace(valor incial,valor final,1)
solucion=fsolve(interseccion,x)

print(f'El punto de intersección de las rectas se tiene cuando x={solucion[0]}')

# %% [markdown]
# ## Determinar puntos de intersección de funciones polinomiales P(x) y Q(x)

# %%
import numpy as np
from scipy.optimize import fsolve

def P(x):
  return #expresión algebraica

#Costos de operación
def Q(x):
  return #expresión algebraica

#Definiendo la función igualada a cero
def interseccion(x):
  return P(x) - Q(x)

x = np.linspace(inicial,final, 2)

solucion = fsolve(interseccion, x)


print(f'La intersección se tiene para  x = {solucion}.')
